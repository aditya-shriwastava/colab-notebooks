# %% [markdown]
# # To do:
# 1. [x] Read about the dataset
# 2. [x] Download the dataset
# 3. [x] Load dataset in jupyter notebook

# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import voc_utils
import matplotlib.pyplot as plt

# %%
cow_train = voc_utils._load_data("cow", "train")
cow0_img = voc_utils.load_img(cow_train.loc[0].fname.split(".")[0])
plt.imshow(cow0_img)
plt.show()

print(cow_train)

cow0_xmin = int(df.loc[0].xmin)
cow0_ymin = int(df.loc[0].ymin)
cow0_xmax = int(df.loc[0].xmax)
cow0_ymax = int(df.loc[0].ymax)
cow0_bbox = [cow0_xmin, cow0_ymin, cow0_xmax, cow0_ymax]
print(cow0_bbox)
# Out:
#                fname  xmin  ymin  xmax  ymax
# 0    2008_000335.jpg    93    89   360   260
# 1    2008_000335.jpg     1    93   110   224
# 2    2008_000335.jpg   441   173   489   191
# 3    2008_000335.jpg   360   175   391   189
# 4    2008_000711.jpg     1     5   294   240
# ..               ...   ...   ...   ...   ...
# 342  2011_002937.jpg   187   199   260   300
# 343  2011_002937.jpg   101   159   183   301
# 344  2011_002979.jpg   217   171   267   191
# 345  2011_002979.jpg   275   146   298   155
# 346  2011_003016.jpg   179   124   395   276
#
# [347 rows x 5 columns]
# [93, 89, 360, 260]
